# %% [markdown]
# ---
# title: Multi-step reaction kinetics
# ---

# %% [markdown]
# ## Time of chemical reactions proceeding through multiple intermediate states

# %% [markdown]
# ![](images/benzoin_condensation.png)
