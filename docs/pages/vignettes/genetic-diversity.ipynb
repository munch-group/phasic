# %% [markdown]
# ---
# title: Genetic diversity
# ---

# %% [markdown]
# ## Differences between DNA sequences accumulated along the ancestral lineages eventually coalescing into a single ancestor

# %% [markdown]
# ![](images/treesequence.svg)
